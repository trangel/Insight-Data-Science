# %%
import sys, os
import nltk
import pandas as pd

# %%
from collections import defaultdict
from gensim import corpora, models, similarities
def make_dictionary(documents):
    """
    construct a dictionary, i.e. mapping btwn word ids and their freq of occurence in the whole corpus
    filter dictionary to remove stopwords and words occuring < min_count times
    
    input: documents is an iterable consisting of all the words in the corpus 
    output: filtered dictionary
    """

    
    dictionary = corpora.Dictionary(documents)

    stop_words = nltk.corpus.stopwords.words('english') 
    min_count = 2
    stop_ids = [dictionary.token2id[word] for word in stop_words
               if word in dictionary.token2id]
    rare_ids = [id for id, freq in dictionary.dfs.items()
                if freq < min_count]
    dictionary.filter_tokens(stop_ids + rare_ids)
    dictionary.compactify()
    return(dictionary)

def make_corpus(documents):
    """
    """
    dictionary = make_dictionary(documents)
    # convert corpus to vectors using bag-of-words representation, i.e. tuples of word indices and word counts
    corpus = [dictionary.doc2bow(words) for words in documents]
    return(corpus, dictionary)

def make_lsi_similarity_matrix(tfidf_corpus, dictionary):
    """
    construct LSI (latent semantic indexing) model on Tfidf-transformed corpus, print model topics, 
    return similarity matrix.
    """
    # construct model
    lsi = models.lsimodel.LsiModel(tfidf_corpus, id2word=dictionary, num_topics=1000) 
    lsi.save('lsi-model.save')
    # create similarity matrix
    matsim = similarities.MatrixSimilarity(lsi[tfidf_corpus], num_best=1000)
    return(matsim)

def make_lda_similarity_matrix(corpus, dictionary):
    """
    Latent Dirichlet Allocation (LDA) model
    """
    # construct model
    lda = models.ldamodel.LdaModel(corpus, id2word=dictionary, num_topics=100)
    lda.save('lda-model.save')
    # create similarity matrix
    matsim = similarities.MatrixSimilarity(lda[corpus], num_best=1000)
    return(matsim)

# %%
# Read database of data
os.chdir('../data')

output_fname="articles-n-forums-posts.csv"

# Read articles from file
input_fname="AutismParentMagazine-posts-clean.csv"
df=pd.read_csv(input_fname,index_col=0)
df.index.name='post id'
df.head(1)
# Out:
#                                                      title  \
# post id
# 0        Autism, Head Banging and other Self Harming Be...
#
#                                            source  \
# post id
# 0        https://www.autismparentingmagazine.com/
#
#                                            category  \
# post id
# 0        ['category-applied-behavior-analysis-aba']
#
#                                                       text  \
# post id
# 0        For children with autism spectrum disorder (AS...
#
#                                                       href
# post id
# 0        https://www.autismparentingmagazine.com/autism...

# %%
# Read articles from file
input_fname="ehealthforum-posts-clean.csv"
df2=pd.read_csv(input_fname,index_col=0)
df2.index.name='post id'
df2['source']='http://ehealthforum.com'
df2['category']='forums'
df2.head(1)
# Out:
#                            title  \
# post id
# 1        Possible autism signs ?
#
#                                                       text  \
# post id
# 1        my nephew who is four years has very bad mood ...
#
#                                                       href  user id  \
# post id
# 1        http://ehealthforum.com/health/possible-autism...  55473.0
#
#          mother post id                   source category
# post id
# 1                     0  http://ehealthforum.com   forums

# %%
input_fname="MedHelp-posts-clean.csv"
df3=pd.read_csv(input_fname,index_col=0)
df3['source']='http://www.medhelp.org'
df3['category']='forums'

#
#Remove questions from forum:
df3=df3.drop(df3.loc[df3.index == df3['mother post id']].index)
del df3['mother post id']
del df3['user id']
df3.head(1)
# Out:
#                                             title  \
# post id
# 2        Inappropriate Masterbation Down Syndrome
#
#                                                       text  \
# post id
# 2        A related discussion, self injusry in masturba...
#
#                                                       href  \
# post id
# 2        http://www.medhelp.org//posts/Autism--Asperger...
#
#                          source category
# post id
# 2        http://www.medhelp.org   forums

# %%
# Read articles from file
input_fname="reditt-posts.csv"
df4=pd.read_csv(input_fname,index_col=0)
df4.index.name='post id'
df4['source']='http://www.reditt.com'
df4['category']='forums'
df4.head(1)
# Out:
#                                  title  \
# post id
# 1        Sulfur and sulfates question.
#
#                                                       text  \
# post id
# 1        I have been subbing in a special education cla...
#
#                                                       href  user id  \
# post id
# 1        http://www.reddit.com/r/autism/comments/1xuenq...        0
#
#                         source category
# post id
# 1        http://www.reditt.com   forums

# %%
# Join datasets
print(len(df))
df=df.append(df2,ignore_index=True)
print(len(df))
df=df.append(df3,ignore_index=True)
print(len(df))
df=df.append(df4,ignore_index=True)
print(len(df))
del df2
del df3
del df4

# delete mother post id
del df['mother post id']
# Out:
# 212
# 1272
# 2249
# 3776

# %%
df.index.name='post id'

# %%
# Make shorter version of reference:

def short_ref(href):
    if 'autismparentingmagazine' in href:
        return 'AutismParentingMagazine'
    elif 'medhelp' in href:
        return 'MedHelp'
    elif 'ehealthforum' in href:
        return 'eHealthForum'
    elif 'reddit' in href:
        return 'Reddit'

df['href_short'] = df['href'].apply(short_ref)
# Out:
#                                            category  \
# post id
# 0        ['category-applied-behavior-analysis-aba']
#
#                                                       href  \
# post id
# 0        https://www.autismparentingmagazine.com/autism...
#
#                                            source  \
# post id
# 0        https://www.autismparentingmagazine.com/
#
#                                                       text  \
# post id
# 0        For children with autism spectrum disorder (AS...
#
#                                                      title  user id  \
# post id
# 0        Autism, Head Banging and other Self Harming Be...      NaN
#
#                       href_short
# post id
# 0        AutismParentingMagazine

# %%
df.head(300)
# Out:
#                                            category  \
# post id
# 0        ['category-applied-behavior-analysis-aba']
# 1        ['category-applied-behavior-analysis-aba']
# 2        ['category-applied-behavior-analysis-aba']
# 3        ['category-applied-behavior-analysis-aba']
# 4        ['category-applied-behavior-analysis-aba']
# 5        ['category-applied-behavior-analysis-aba']
# 6                      ['category-autism-advocacy']
# 7                      ['category-autism-advocacy']
# 8                      ['category-autism-advocacy']
# 9                      ['category-autism-advocacy']
# 10                     ['category-autism-advocacy']
# 11                     ['category-autism-advocacy']
# 12                     ['category-autism-advocacy']
# 13                     ['category-autism-advocacy']
# 14                     ['category-autism-advocacy']
# 15                     ['category-autism-advocacy']
# 16                     ['category-autism-and-diet']
# 17                     ['category-autism-and-diet']
# 18                     ['category-autism-and-diet']
# 19                     ['category-autism-and-diet']
# 20                     ['category-autism-and-food']
# 21                     ['category-autism-and-food']
# 22                     ['category-autism-articles']
# 23                     ['category-autism-articles']
# 24                     ['category-autism-articles']
# 25                     ['category-autism-articles']
# 26                     ['category-autism-articles']
# 27                     ['category-autism-articles']
# 28                     ['category-autism-articles']
# 29                     ['category-autism-articles']
# ...                                             ...
# 270                                          forums
# 271                                          forums
# 272                                          forums
# 273                                          forums
# 274                                          forums
# 275                                          forums
# 276                                          forums
# 277                                          forums
# 278                                          forums
# 279                                          forums
# 280                                          forums
# 281                                          forums
# 282                                          forums
# 283                                          forums
# 284                                          forums
# 285                                          forums
# 286                                          forums
# 287                                          forums
# 288                                          forums
# 289                                          forums
# 290                                          forums
# 291                                          forums
# 292                                          forums
# 293                                          forums
# 294                                          forums
# 295                                          forums
# 296                                          forums
# 297                                          forums
# 298                                          forums
# 299                                          forums
#
#                                                       href  \
# post id
# 0        https://www.autismparentingmagazine.com/autism...
# 1        https://www.autismparentingmagazine.com/high-q...
# 2        https://www.autismparentingmagazine.com/choosi...
# 3        https://www.autismparentingmagazine.com/help-a...
# 4        https://www.autismparentingmagazine.com/help-i...
# 5        https://www.autismparentingmagazine.com/help-m...
# 6        https://www.autismparentingmagazine.com/autism...
# 7        https://www.autismparentingmagazine.com/restau...
# 8        https://www.autismparentingmagazine.com/lloyd-...
# 9        https://www.autismparentingmagazine.com/erasin...
# 10       https://www.autismparentingmagazine.com/the-ne...
# 11       https://www.autismparentingmagazine.com/how-on...
# 12       https://www.autismparentingmagazine.com/winnin...
# 13       https://www.autismparentingmagazine.com/autism...
# 14       https://www.autismparentingmagazine.com/bridge...
# 15       https://www.autismparentingmagazine.com/exposi...
# 16       https://www.autismparentingmagazine.com/gluten...
# 17       https://www.autismparentingmagazine.com/asperg...
# 18       https://www.autismparentingmagazine.com/six-st...
# 19       https://www.autismparentingmagazine.com/qa-sec...
# 20       https://www.autismparentingmagazine.com/mallor...
# 21       https://www.autismparentingmagazine.com/sugary...
# 22       https://www.autismparentingmagazine.com/social...
# 23       https://www.autismparentingmagazine.com/ways-h...
# 24       https://www.autismparentingmagazine.com/autism...
# 25       https://www.autismparentingmagazine.com/mental...
# 26       https://www.autismparentingmagazine.com/help-a...
# 27       https://www.autismparentingmagazine.com/raisin...
# 28       https://www.autismparentingmagazine.com/servic...
# 29       https://www.autismparentingmagazine.com/signs-...
# ...                                                    ...
# 270      http://ehealthforum.com/health/is-it-possible-...
# 271      http://ehealthforum.com/health/is-it-possible-...
# 272      http://ehealthforum.com/health/can-autism-be-g...
# 273      http://ehealthforum.com/health/can-autism-be-g...
# 274      http://ehealthforum.com/health/can-autism-be-g...
# 275      http://ehealthforum.com/health/can-autism-be-g...
# 276      http://ehealthforum.com/health/can-autism-be-g...
# 277      http://ehealthforum.com/health/can-autism-be-g...
# 278      http://ehealthforum.com/health/can-autism-be-g...
# 279      http://ehealthforum.com/health/can-autism-be-g...
# 280      http://ehealthforum.com/health/how-autism-affe...
# 281      http://ehealthforum.com/health/how-autism-affe...
# 282        http://ehealthforum.com/health/topic116210.html
# 283        http://ehealthforum.com/health/topic116210.html
# 284        http://ehealthforum.com/health/topic116210.html
# 285        http://ehealthforum.com/health/topic116210.html
# 286        http://ehealthforum.com/health/topic116210.html
# 287        http://ehealthforum.com/health/topic116210.html
# 288        http://ehealthforum.com/health/topic116210.html
# 289        http://ehealthforum.com/health/topic116210.html
# 290        http://ehealthforum.com/health/topic116210.html
# 291        http://ehealthforum.com/health/topic116210.html
# 292        http://ehealthforum.com/health/topic116210.html
# 293        http://ehealthforum.com/health/topic116210.html
# 294        http://ehealthforum.com/health/topic116210.html
# 295        http://ehealthforum.com/health/topic116210.html
# 296        http://ehealthforum.com/health/topic116210.html
# 297        http://ehealthforum.com/health/topic116210.html
# 298        http://ehealthforum.com/health/topic116210.html
# 299        http://ehealthforum.com/health/topic116210.html
#
#                                            source  \
# post id
# 0        https://www.autismparentingmagazine.com/
# 1        https://www.autismparentingmagazine.com/
# 2        https://www.autismparentingmagazine.com/
# 3        https://www.autismparentingmagazine.com/
# 4        https://www.autismparentingmagazine.com/
# 5        https://www.autismparentingmagazine.com/
# 6        https://www.autismparentingmagazine.com/
# 7        https://www.autismparentingmagazine.com/
# 8        https://www.autismparentingmagazine.com/
# 9        https://www.autismparentingmagazine.com/
# 10       https://www.autismparentingmagazine.com/
# 11       https://www.autismparentingmagazine.com/
# 12       https://www.autismparentingmagazine.com/
# 13       https://www.autismparentingmagazine.com/
# 14       https://www.autismparentingmagazine.com/
# 15       https://www.autismparentingmagazine.com/
# 16       https://www.autismparentingmagazine.com/
# 17       https://www.autismparentingmagazine.com/
# 18       https://www.autismparentingmagazine.com/
# 19       https://www.autismparentingmagazine.com/
# 20       https://www.autismparentingmagazine.com/
# 21       https://www.autismparentingmagazine.com/
# 22       https://www.autismparentingmagazine.com/
# 23       https://www.autismparentingmagazine.com/
# 24       https://www.autismparentingmagazine.com/
# 25       https://www.autismparentingmagazine.com/
# 26       https://www.autismparentingmagazine.com/
# 27       https://www.autismparentingmagazine.com/
# 28       https://www.autismparentingmagazine.com/
# 29       https://www.autismparentingmagazine.com/
# ...                                           ...
# 270                       http://ehealthforum.com
# 271                       http://ehealthforum.com
# 272                       http://ehealthforum.com
# 273                       http://ehealthforum.com
# 274                       http://ehealthforum.com
# 275                       http://ehealthforum.com
# 276                       http://ehealthforum.com
# 277                       http://ehealthforum.com
# 278                       http://ehealthforum.com
# 279                       http://ehealthforum.com
# 280                       http://ehealthforum.com
# 281                       http://ehealthforum.com
# 282                       http://ehealthforum.com
# 283                       http://ehealthforum.com
# 284                       http://ehealthforum.com
# 285                       http://ehealthforum.com
# 286                       http://ehealthforum.com
# 287                       http://ehealthforum.com
# 288                       http://ehealthforum.com
# 289                       http://ehealthforum.com
# 290                       http://ehealthforum.com
# 291                       http://ehealthforum.com
# 292                       http://ehealthforum.com
# 293                       http://ehealthforum.com
# 294                       http://ehealthforum.com
# 295                       http://ehealthforum.com
# 296                       http://ehealthforum.com
# 297                       http://ehealthforum.com
# 298                       http://ehealthforum.com
# 299                       http://ehealthforum.com
#
#                                                       text  \
# post id
# 0        For children with autism spectrum disorder (AS...
# 1        Dr. Stephen Shore once said “If you’ve met one...
# 2         Help! I am going to be starting Applied Behav...
# 3        How do you handle high anxiety of a child on t...
# 4        A grandfather from Singapore asks… My eldest g...
# 5        Hi, I am the parent of a 13-year-old boy with ...
# 6        It will be some time before we see a positive ...
# 7        Restaurant owner Andrew Iredale could hardly b...
# 8        Autism can be one of the most difficult diagno...
# 9        An Interview with Dr. Tony Attwood, PhD, AS/AS...
# 10       A civil rights lawyer and autism mom talks abo...
# 11       In two short years, Tikko has captured the hea...
# 12       Every time the professional fighters meet thei...
# 13       Autism Services for Military Families by Lesli...
# 14       Bridge the Gap Gala Raises over $100,000 by Le...
# 15         We started this magazine to help parents, so...
# 16       Recent clinical trials looking at gluten-free ...
# 17       I find the suggestion that there needs to be a...
# 18       “Wow, how did you get him/her to do that?,” pa...
# 19       This is the question of the month as featured ...
# 20       I had the pleasure of reviewing Mallory’s Marv...
# 21       Sivakumari asks: My daughter loves to eat ice-...
# 22       Children with autism spectrum disorder (ASD) c...
# 23       How does your child react in the water—with pl...
# 24       Over the years, lack of eye contact from a per...
# 25       If your child has autism spectrum disorder (AS...
# 26       Lately, the news has been immersed in images o...
# 27       When we brought my seven-year-old stepdaughter...
# 28       Families navigating through the world of autis...
# 29       Early signs of autism spectrum disorder (ASD) ...
# ...                                                    ...
# 270      While yes ASD is significantly related to gene...
# 271      Regarding your dilemma about yourself, if you ...
# 272      i am 15 years old and was diagnosed with autis...
# 273      My 10 year old son has autism and I have studi...
# 274      I was diagnosed with Asperger's syndrome as a ...
# 275      My name is Joseph. I have a daughter diagnosed...
# 276      One can not grow out of autism, but coping str...
# 277      There's evidence suggesting that gluten sensit...
# 278      Totally overcoming is not possible. But skills...
# 279      A big question from parents of kids with ADHD ...
# 280      want to know how the Autism disease affects th...
# 281      Children with autism spectrum disorder (ASD) d...
# 282      im 17 and last yera i found out i have autism ...
# 283      unfortunatly to date there is no cure for auti...
# 284      well i find it really hard 2 talk 2 other peop...
# 285      I dont have autism but i have a very hard time...
# 286      We never want to let the years pass by in weak...
# 287      Hey! You can get help. You should see a psycho...
# 288      I was a complete skeptic regarding alternative...
# 289      Been using it myself for general health. The b...
# 290      anything with omega3 in it is good for the bra...
# 291      more than likely---ive seen some adults use it...
# 292                             ok thank you i will try it
# 293                             let us know how it works:)
# 294      I did the same thing with my son who is on the...
# 295      yeah and remember that everyone is different a...
# 296                                         ok yeap thanks
# 297      Personally, I has a similar problem myself wit...
# 298                        Right  Thank god for caller ID.
# 299      oh i agree completely with that. id bee doomed...
#
#                                                      title   user id  \
# post id
# 0        Autism, Head Banging and other Self Harming Be...       NaN
# 1        High Quality ABA Treatment:  What Every Parent...       NaN
# 2        Help: I Don’t Know How to Choose an Applied Be...       NaN
# 3        HELP: My Autistic Child is Absolutely Terrifie...       NaN
# 4        HELP: I Need Communication Advice for Autistic...       NaN
# 5                          Help: My Aspie Lacks Motivation       NaN
# 6        Exciting Campaign Launched to Tackle the Autis...       NaN
# 7        How One Restaurateur Makes Eating Out Autism-F...       NaN
# 8                         Lloyd Claycomb’s Views on Autism       NaN
# 9        Erasing the Prejudice – Are People on the Spec...       NaN
# 10       The Never Ending Battle for Autism Rights – A ...       NaN
# 11       How One Special Bear Changed the Way People Se...       NaN
# 12                            Winning the Fight for Autism       NaN
# 13       The Right for Autism Services for U.S. Militar...       NaN
# 14                Bridge the Gap Gala Raises over $100,000       NaN
# 15                      Exposing Autism Speaks – Podcast 4       NaN
# 16       Top Ways a Gluten Free Diet  Can Help Kids wit...       NaN
# 17        Asperger’s Syndrome and the Power of a Good Diet       NaN
# 18       Six Steps to a Fun, Friendly, Family Fitness P...       NaN
# 19       Q&A Section: How does Gluten free casein free ...       NaN
# 20                             Mallory’s Marvelous Muffins       NaN
# 21       Q and A Do sugary foods make children with aut...       NaN
# 22                    Social Stories for Autistic Children       NaN
# 23       Creative Ways to Help a Child with Autism Enjo...       NaN
# 24       Autism and Anxiety Disorder – The Double Diagn...       NaN
# 25       Mental Health and Anxiety Treatment with Autis...       NaN
# 26       Helping People With Autism Communicate in a Di...       NaN
# 27       I See You: Raising Neurotypical and Autistic S...       NaN
# 28       The Awesome Rewards of a School Service Dog fo...       NaN
# 29                 Signs of Autism in Infants and Children       NaN
# ...                                                    ...       ...
# 270        is it possible that my kids got autism from me?  630934.0
# 271        is it possible that my kids got autism from me?  675981.0
# 272                           can autism be grown out of ?  578954.0
# 273                           can autism be grown out of ?  579216.0
# 274                           can autism be grown out of ?  605369.0
# 275                           can autism be grown out of ?  605429.0
# 276                           can autism be grown out of ?  313175.0
# 277                           can autism be grown out of ?  607499.0
# 278                           can autism be grown out of ?  621617.0
# 279                           can autism be grown out of ?  607499.0
# 280             How Autism Affects the Growth of the Child  709539.0
# 281             How Autism Affects the Growth of the Child  724934.0
# 282                           Can You Cure Autsim (Page 1)   92304.0
# 283                           Can You Cure Autsim (Page 1)   71395.0
# 284                           Can You Cure Autsim (Page 1)   92304.0
# 285                           Can You Cure Autsim (Page 1)   71395.0
# 286                           Can You Cure Autsim (Page 1)   55269.0
# 287                           Can You Cure Autsim (Page 1)   91919.0
# 288                           Can You Cure Autsim (Page 1)   82225.0
# 289                           Can You Cure Autsim (Page 1)   55269.0
# 290                           Can You Cure Autsim (Page 1)   71395.0
# 291                           Can You Cure Autsim (Page 1)   71395.0
# 292                           Can You Cure Autsim (Page 1)   92304.0
# 293                           Can You Cure Autsim (Page 1)   71395.0
# 294                           Can You Cure Autsim (Page 1)  116173.0
# 295                           Can You Cure Autsim (Page 1)   71395.0
# 296                           Can You Cure Autsim (Page 1)   92304.0
# 297                           Can You Cure Autsim (Page 1)  123989.0
# 298                           Can You Cure Autsim (Page 1)   91919.0
# 299                           Can You Cure Autsim (Page 1)   71395.0
#
#                       href_short  \
# post id
# 0        AutismParentingMagazine
# 1        AutismParentingMagazine
# 2        AutismParentingMagazine
# 3        AutismParentingMagazine
# 4        AutismParentingMagazine
# 5        AutismParentingMagazine
# 6        AutismParentingMagazine
# 7        AutismParentingMagazine
# 8        AutismParentingMagazine
# 9        AutismParentingMagazine
# 10       AutismParentingMagazine
# 11       AutismParentingMagazine
# 12       AutismParentingMagazine
# 13       AutismParentingMagazine
# 14       AutismParentingMagazine
# 15       AutismParentingMagazine
# 16       AutismParentingMagazine
# 17       AutismParentingMagazine
# 18       AutismParentingMagazine
# 19       AutismParentingMagazine
# 20       AutismParentingMagazine
# 21       AutismParentingMagazine
# 22       AutismParentingMagazine
# 23       AutismParentingMagazine
# 24       AutismParentingMagazine
# 25       AutismParentingMagazine
# 26       AutismParentingMagazine
# 27       AutismParentingMagazine
# 28       AutismParentingMagazine
# 29       AutismParentingMagazine
# ...                          ...
# 270                 eHealthForum
# 271                 eHealthForum
# 272                 eHealthForum
# 273                 eHealthForum
# 274                 eHealthForum
# 275                 eHealthForum
# 276                 eHealthForum
# 277                 eHealthForum
# 278                 eHealthForum
# 279                 eHealthForum
# 280                 eHealthForum
# 281                 eHealthForum
# 282                 eHealthForum
# 283                 eHealthForum
# 284                 eHealthForum
# 285                 eHealthForum
# 286                 eHealthForum
# 287                 eHealthForum
# 288                 eHealthForum
# 289                 eHealthForum
# 290                 eHealthForum
# 291                 eHealthForum
# 292                 eHealthForum
# 293                 eHealthForum
# 294                 eHealthForum
# 295                 eHealthForum
# 296                 eHealthForum
# 297                 eHealthForum
# 298                 eHealthForum
# 299                 eHealthForum
#
#                                                     tokens  \
# post id
# 0        [autism, head, bang, and, other, self, harm, b...
# 1        [high, quality, aba, treatment, what, every, p...
# 2        [help, i, don, t, know, how, to, choose, an, a...
# 3        [help, my, autistic, child, be, absolutely, te...
# 4        [help, i, need, communication, advice, for, au...
# 5        [help, my, aspie, lack, motivation, hi, i, be,...
# 6        [excite, campaign, launch, to, tackle, the, au...
# 7        [how, one, restaurateur, make, eat, out, autis...
# 8        [lloyd, claycomb, s, view, on, autism, autism,...
# 9        [erase, the, prejudice, be, people, on, the, s...
# 10       [the, never, end, battle, for, autism, right, ...
# 11       [how, one, special, bear, change, the, way, pe...
# 12       [win, the, fight, for, autism, every, time, th...
# 13       [the, right, for, autism, service, for, u, s, ...
# 14       [bridge, the, gap, gala, raise, over, 100, 000...
# 15       [expose, autism, speak, podcast, 4, we, start,...
# 16       [top, ways, a, gluten, free, diet, can, help, ...
# 17       [asperger, s, syndrome, and, the, power, of, a...
# 18       [six, step, to, a, fun, friendly, family, fitn...
# 19       [q, a, section, how, do, gluten, free, casein,...
# 20       [mallory, s, marvelous, muffins, i, have, the,...
# 21       [q, and, a, do, sugary, foods, make, children,...
# 22       [social, stories, for, autistic, children, chi...
# 23       [creative, ways, to, help, a, child, with, aut...
# 24       [autism, and, anxiety, disorder, the, double, ...
# 25       [mental, health, and, anxiety, treatment, with...
# 26       [help, people, with, autism, communicate, in, ...
# 27       [i, see, you, raise, neurotypical, and, autist...
# 28       [the, awesome, reward, of, a, school, service,...
# 29       [sign, of, autism, in, infants, and, children,...
# ...                                                    ...
# 270      [be, it, possible, that, my, kid, get, autism,...
# 271      [be, it, possible, that, my, kid, get, autism,...
# 272      [can, autism, be, grow, out, of, i, be, 15, ye...
# 273      [can, autism, be, grow, out, of, my, 10, year,...
# 274      [can, autism, be, grow, out, of, i, be, diagno...
# 275      [can, autism, be, grow, out, of, my, name, be,...
# 276      [can, autism, be, grow, out, of, one, can, not...
# 277      [can, autism, be, grow, out, of, there, s, evi...
# 278      [can, autism, be, grow, out, of, totally, over...
# 279      [can, autism, be, grow, out, of, a, big, quest...
# 280      [how, autism, affect, the, growth, of, the, ch...
# 281      [how, autism, affect, the, growth, of, the, ch...
# 282      [can, you, cure, autsim, page, 1, im, 17, and,...
# 283      [can, you, cure, autsim, page, 1, unfortunatly...
# 284      [can, you, cure, autsim, page, 1, well, i, fin...
# 285      [can, you, cure, autsim, page, 1, i, dont, hav...
# 286      [can, you, cure, autsim, page, 1, we, never, w...
# 287      [can, you, cure, autsim, page, 1, hey, you, ca...
# 288      [can, you, cure, autsim, page, 1, i, be, a, co...
# 289      [can, you, cure, autsim, page, 1, be, use, it,...
# 290      [can, you, cure, autsim, page, 1, anything, wi...
# 291      [can, you, cure, autsim, page, 1, more, than, ...
# 292      [can, you, cure, autsim, page, 1, ok, thank, y...
# 293      [can, you, cure, autsim, page, 1, let, us, kno...
# 294      [can, you, cure, autsim, page, 1, i, do, the, ...
# 295      [can, you, cure, autsim, page, 1, yeah, and, r...
# 296      [can, you, cure, autsim, page, 1, ok, yeap, th...
# 297      [can, you, cure, autsim, page, 1, personally, ...
# 298      [can, you, cure, autsim, page, 1, right, thank...
# 299      [can, you, cure, autsim, page, 1, oh, i, agree...
#
#                                                 text_short
# post id
# 0        For children with autism spectrum disorder (AS...
# 1        Dr. Stephen Shore once said “If you’ve met one...
# 2         Help! I am going to be starting Applied Behav...
# 3        How do you handle high anxiety of a child on t...
# 4        A grandfather from Singapore asks… My eldest g...
# 5        Hi, I am the parent of a 13-year-old boy with ...
# 6        It will be some time before we see a positive ...
# 7        Restaurant owner Andrew Iredale could hardly b...
# 8        Autism can be one of the most difficult diagno...
# 9        An Interview with Dr. Tony Attwood, PhD, AS/AS...
# 10       A civil rights lawyer and autism mom talks abo...
# 11       In two short years, Tikko has captured the hea...
# 12       Every time the professional fighters meet thei...
# 13       Autism Services for Military Families by Lesli...
# 14       Bridge the Gap Gala Raises over $100,000 by Le...
# 15         We started this magazine to help parents, so...
# 16       Recent clinical trials looking at gluten-free ...
# 17       I find the suggestion that there needs to be a...
# 18       “Wow, how did you get him/her to do that?,” pa...
# 19       This is the question of the month as featured ...
# 20       I had the pleasure of reviewing Mallory’s Marv...
# 21       Sivakumari asks: My daughter loves to eat ice-...
# 22       Children with autism spectrum disorder (ASD) c...
# 23       How does your child react in the water—with pl...
# 24       Over the years, lack of eye contact from a per...
# 25       If your child has autism spectrum disorder (AS...
# 26       Lately, the news has been immersed in images o...
# 27       When we brought my seven-year-old stepdaughter...
# 28       Families navigating through the world of autis...
# 29       Early signs of autism spectrum disorder (ASD) ...
# ...                                                    ...
# 270      While yes ASD is significantly related to gene...
# 271      Regarding your dilemma about yourself, if you ...
# 272      i am 15 years old and was diagnosed with autis...
# 273      My 10 year old son has autism and I have studi...
# 274      I was diagnosed with Asperger's syndrome as a ...
# 275      My name is Joseph. I have a daughter diagnosed...
# 276      One can not grow out of autism, but coping str...
# 277      There's evidence suggesting that gluten sensit...
# 278      Totally overcoming is not possible. But skills...
# 279      A big question from parents of kids with ADHD ...
# 280      want to know how the Autism disease affects th...
# 281      Children with autism spectrum disorder (ASD) d...
# 282      im 17 and last yera i found out i have autism ...
# 283      unfortunatly to date there is no cure for auti...
# 284      well i find it really hard 2 talk 2 other peop...
# 285      I dont have autism but i have a very hard time...
# 286      We never want to let the years pass by in weak...
# 287      Hey! You can get help. You should see a psycho...
# 288      I was a complete skeptic regarding alternative...
# 289      Been using it myself for general health. The b...
# 290      anything with omega3 in it is good for the bra...
# 291      more than likely---ive seen some adults use it...
# 292                             ok thank you i will try it
# 293                             let us know how it works:)
# 294      I did the same thing with my son who is on the...
# 295      yeah and remember that everyone is different a...
# 296                                         ok yeap thanks
# 297      Personally, I has a similar problem myself wit...
# 298                        Right  Thank god for caller ID.
# 299      oh i agree completely with that. id bee doomed...
#
# [300 rows x 9 columns]

# %%
# Tokenize data
import nltk
tokenizer = nltk.RegexpTokenizer(r'\w+')

# Get list of tokens from text in first article:
text = df['text'][0].lower()
# Add also title:
title = df['title'][0].lower()
ttext = tokenizer.tokenize(title+" "+text)

# %%
# Get a column with list of tokens:

# 1) convert to lower case 
# 2) get tokens
# 2) save data in a new column (tokens)
#df['tokens'] = df['text'].map(lambda x: tokenizer.tokenize(x.lower()))

# Join title and text into one column
df2=df[['title','text']].apply(lambda x: ','.join(x.astype(str)),axis=1)
df['tokens'] = df2.map(lambda x: tokenizer.tokenize(x.lower()))
del df2

# %%
# Short version of text
df['text_short']=df['text'].apply(lambda x: x[:200]+" (...)" if (len(x) > 200) else x)

# %%
# Lematize

from nltk.stem.wordnet import WordNetLemmatizer

for ii in df.index:
    tokens = df.loc[ii,'tokens']
    lemas=[]
    for word in tokens:
        ww=WordNetLemmatizer().lemmatize(word,'v')
        lemas.append(ww)
    df.set_value(ii,'tokens',lemas)

#

# %%
# Save dataframe with tokens into files
df.to_csv(output_fname)

# %%
# Get similarity matrices
documents = df['tokens'].values
print(documents[:3])
corpus,dictionary = make_corpus(documents)

#Save corpus into file
import pickle
pickle.dump(dictionary,open("dictionary.save","wb"))
pickle.dump(corpus,open("corpus.save", "wb"))

tfidf = models.TfidfModel(corpus)
tfidf.save('tfidf.save')

lsi_matsim = make_lsi_similarity_matrix(tfidf[corpus], dictionary)
lda_matsim = make_lda_similarity_matrix(corpus, dictionary)

# The models are saved into files in the above routines
# Save similarity matrices too:
pickle.dump(lsi_matsim,open("lsi-matsim.save","wb"))
pickle.dump(lda_matsim,open("lda-matsim.save","wb"))
# Out:
# [ ['autism', 'head', 'bang', 'and', 'other', 'self', 'harm', 'behavior', 'for', 'children', 'with', 'autism', 'spectrum', 'disorder', 'asd', 'head', 'bang', 'be', 'a', 'common', 'way', 'to', 'self', 'soothe', 'and', 'communicate', 'need', 'both', 'neurotypical', 'and', 'autistic', 'baby', 'and', 'toddlers', 'seek', 'to', 'recreate', 'the', 'rhythm', 'that', 'stimulate', 'their', 'vestibular', 'system', 'while', 'in', 'utero', 'other', 'rhythmic', 'habit', 'that', 'fuel', 'a', 'child', 's', 'kinesthetic', 'drive', 'include', 'head', 'roll', 'body', 'rock', 'bite', 'and', 'thumb']
#  ['high', 'quality', 'aba', 'treatment', 'what', 'every', 'parent', 'need', 'to', 'know', 'dr', 'stephen', 'shore', 'once', 'say', 'if', 'you', 've', 'meet', 'one', 'person', 'with', 'autism', 'you', 've', 'meet', 'one', 'person', 'with', 'autism', 'as', 'many', 'of', 'you', 'know', 'the', 'centre', 'for', 'disease', 'control', 'and', 'prevention', 'report', 'that', 'there', 'be', 'now', '1', 'in', '68', 'children', 'live', 'with', 'autism', 'in', 'the', 'unite', 'state', 'what', 'this', 'mean', 'for', 'each', 'child', 'and', 'his', 'her', 'family']
#  ['help', 'i', 'don', 't', 'know', 'how', 'to', 'choose', 'an', 'apply', 'behavior', 'analysis', 'provider', 'help', 'i', 'be', 'go', 'to', 'be', 'start', 'apply', 'behavior', 'analysis', 'for', 'my', 'son', 'who', 'have', 'autism', 'can', 'you', 'tell', 'me', 'things', 'to', 'ask', 'and', 'what', 'to', 'look', 'for', 'in', 'an', 'aba', 'provider', 'jane', 'i', 'be', 'so', 'glad', 'you', 'ask', 'this', 'within', 'the', 'autism', 'community', 'there', 'be', 'mix', 'feel', 'about', 'apply', 'behavior', 'analysis', 'aba', 'but']]
