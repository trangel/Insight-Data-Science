# %% [markdown]
# This aims to get relevant data from:
# https://www.autismparentingmagazine.com/applied-behavior-analysis-aba/

# %%
import requests  # to make GET request
from bs4 import BeautifulSoup  # to parse the HTML response
import time  # to pause between calls
import pandas as pd  # to see CSV
import os

# %%
def parse_page(response):
    """This parses pages from the Autism Parent Magazine web site using beautifulsoup"""
    global df
    global source
    # parse the response into an HTML tree soup object
    # read the content of the server’s response as a string
    page_source = response.text
    soup = BeautifulSoup(page_source, 'html5lib')
    # take a look
    #print(soup.prettify()[:1000])

    # Find all "<div class="entry-row" appearances
    links=soup.select("div.entry-row")
    for link in links:
        article=link.select("article")
        # Get category (for validation)
        for element in article[0]['class']:
            if ( 'category' in element ):
                category=element
                break
                
        # Get text
        #article[0].find_all('div')[1].get_text()
        text=article[0].find('div', class_='entry-summary entry-content').get_text()
    
        # Get href. for further reading
        href=article[0].find('a')['href']
    
        # Get title
        title=article[0].find('a')['title']
        
        newrow={"title":title,"source":source,"category":category,"text":text,"href":href}

        # Add entry into database
        df.loc[len(df.values)]=newrow

# %%
os.chdir("../data")

# Create an empty database to keep the history of purchases
columns=["title","source","category","text","href"]
df=pd.DataFrame(columns=columns)

# %%
source="https://www.autismparentingmagazine.com/"
    
# Get list of pages to parse:
f = open("AutismParentMagazine-urls.txt","r")
urls =  f.readlines()
f.close()

for ii in range(len(urls)):
    url = urls[ii]
    urls[ii]=url.strip()

# %%
#loop over urls:

for url in urls:
    # make a GET request
    response = requests.get(url)

    parse_page(response)
    time.sleep(5)

# %%
# Convert to file
df.to_csv("AutismParentMagazine-posts.csv")

# %%
df
# Out:
#                                                  title  \
# 0    Autism, Head Banging and other Self Harming Be...
# 1    High Quality ABA Treatment:  What Every Parent...
# 2    Help: I Don’t Know How to Choose an Applied Be...
# 3    HELP: My Autistic Child is Absolutely Terrifie...
# 4    HELP: I Need Communication Advice for Autistic...
# 5                      Help: My Aspie Lacks Motivation
# 6    Exciting Campaign Launched to Tackle the Autis...
# 7    How One Restaurateur Makes Eating Out Autism-F...
# 8                     Lloyd Claycomb’s Views on Autism
# 9    Erasing the Prejudice – Are People on the Spec...
# 10   The Never Ending Battle for Autism Rights – A ...
# 11   How One Special Bear Changed the Way People Se...
# 12                        Winning the Fight for Autism
# 13   The Right for Autism Services for U.S. Militar...
# 14            Bridge the Gap Gala Raises over $100,000
# 15                  Exposing Autism Speaks – Podcast 4
# ...
